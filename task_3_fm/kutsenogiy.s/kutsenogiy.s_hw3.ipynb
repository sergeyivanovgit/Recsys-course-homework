# %%
import pandas as pd
import os
import numpy as np

from sklearn.preprocessing import OneHotEncoder, StandardScaler, LabelEncoder

# %%
from scipy import sparse

# %%
df = pd.read_csv('../../../../data.csv')
df = df.sample(int(len(df) * 0.5), random_state=42).reset_index(False)

# %%
df.oaid_hash = LabelEncoder().fit_transform(df.oaid_hash.values)

# %%
df['rate0'].fillna(np.mean(df[df.date_time < '2021-10-02']['rate0']), inplace=True)
df['g0'].fillna(np.mean(df[df.date_time < '2021-10-02']['g0']), inplace=True)
df['coeff_sum0'].fillna(np.mean(df[df.date_time < '2021-10-02']['coeff_sum0']), inplace=True)

df['rate1'].fillna(np.mean(df[df.date_time < '2021-10-02']['rate1']), inplace=True)
df['g1'].fillna(np.mean(df[df.date_time < '2021-10-02']['g1']), inplace=True)
df['coeff_sum1'].fillna(np.mean(df[df.date_time < '2021-10-02']['coeff_sum1']), inplace=True)

# %%
one_encoder = OneHotEncoder()
scaller = StandardScaler()

# %%
data = sparse.hstack([
    one_encoder.fit_transform(df[['zone_id']]),
    one_encoder.fit_transform(df[['banner_id']]),
    one_encoder.fit_transform(df[['oaid_hash']]),
    one_encoder.fit_transform(df[['zone_id']]),
    one_encoder.fit_transform(df[['os_id']]),
    one_encoder.fit_transform(df[['country_id']]),
    sparse.csr_matrix(scaller.fit_transform(df[['campaign_clicks']])),
    sparse.csr_matrix(scaller.fit_transform(df[['rate0']])),
    sparse.csr_matrix(scaller.fit_transform(df[['g0']])),
    sparse.csr_matrix(scaller.fit_transform(df[['coeff_sum0']])),
    sparse.csr_matrix(scaller.fit_transform(df[['rate1']])),
    sparse.csr_matrix(scaller.fit_transform(df[['g1']])),
    sparse.csr_matrix(scaller.fit_transform(df[['coeff_sum1']])),
])

data = data.tocsr()

# %%
train_index_max = df[df['date_time'] < '2021-10-02'].index
test_index_max = df[df['date_time'] >= '2021-10-02'].index

x_train, x_test = data[train_index_max], data[test_index_max]
y_train, y_test = df.iloc[train_index_max]['clicks'], df.iloc[test_index_max]['clicks']

# %%
from pyfm import pylibfm

# %%
fm = pylibfm.FM(
    num_factors=10,
    num_iter=30,
    verbose=True,
    task='classification',
    initial_learning_rate=0.001,
    learning_rate_schedule="optimal"
)

# %%
fm.fit(x_train, y_train.values)
# Out:
# Creating validation dataset of 0.01 of training for adaptive regularization
# -- Epoch 1
# Training log loss: 0.10670
# -- Epoch 2
# Training log loss: 0.10488
# -- Epoch 3
# Training log loss: 0.10442
# -- Epoch 4
# Training log loss: 0.10408
# -- Epoch 5
# Training log loss: 0.10379
# -- Epoch 6
# Training log loss: 0.10352
# -- Epoch 7
# Training log loss: 0.10324
# -- Epoch 8
# Training log loss: 0.10297
# -- Epoch 9
# Training log loss: 0.10267
# -- Epoch 10
# Training log loss: 0.10241
# -- Epoch 11
# Training log loss: 0.10212
# -- Epoch 12
# Training log loss: 0.10188
# -- Epoch 13
# Training log loss: 0.10162
# -- Epoch 14
# Training log loss: 0.10135
# -- Epoch 15
# Training log loss: 0.10108
# -- Epoch 16
# Training log loss: 0.10085
# -- Epoch 17
# Training log loss: 0.10058
# -- Epoch 18
# Training log loss: 0.10035
# -- Epoch 19
# Training log loss: 0.10013
# -- Epoch 20
# Training log loss: 0.09988
# -- Epoch 21
# Training log loss: 0.09961
# -- Epoch 22
# Training log loss: 0.09939
# -- Epoch 23
# Training log loss: 0.09916
# -- Epoch 24
# Training log loss: 0.09887
# -- Epoch 25
# Training log loss: 0.09866
# -- Epoch 26
# Training log loss: 0.09842
# -- Epoch 27
# Training log loss: 0.09816
# -- Epoch 28
# Training log loss: 0.09791
# -- Epoch 29
# Training log loss: 0.09766
# -- Epoch 30
# Training log loss: 0.09737

# %%
preds = fm.predict(x_test)

# %%
from sklearn.metrics import roc_auc_score, log_loss

# %%
log_loss(y_test.values, preds)
# Out:
# 0.12903765559972247

# %%
roc_auc_score(y_test.values, preds)
# Out:
# 0.8005871025839967

# %% [markdown]
# Получили хорошие метрики, но какой ценой? Очень долго учится, я не знаю какие выводы еще можно сделать, но работает

# %% [markdown]
# ### В общем, тут стало понятно, что для ffm надо все совсем под другому, поэтому хоть это и в одном ноутбуке, но это неправда, тут все будет совсем по-другому)

# %%
df = pd.read_csv('../../../../data.csv')

# %% [markdown]
# Функцию подготовки возьмем с открытого источника на гитхабе

# %%
import json
import math


def _convert_to_ffm(path, df, type, target, numerics, categories, features, encoder):
    print('convert_to_ffm - START')
    for x in numerics:
        if(x not in encoder['catdict']):
            print(f'UPDATING CATDICT: numeric field - {x}')
            encoder['catdict'][x] = 0
    for x in categories:
        if(x not in encoder['catdict']):
            print(f'UPDATING CATDICT: categorical field - {x}')
            encoder['catdict'][x] = 1

    nrows = df.shape[0]
    with open(path + str(type) + "_ffm.txt", "w") as text_file:

        for n, r in enumerate(range(nrows)):
            datastring = ""
            datarow = df.iloc[r].to_dict()
            datastring += str(int(datarow[target]))

            for i, x in enumerate(encoder['catdict'].keys()):
                if(encoder['catdict'][x] == 0):
                    if math.isnan(datarow[x]) is not True:
                        datastring = datastring + " "+str(i)+":" + str(i)+":" + str(datarow[x])
                else:

                    if(x not in encoder['catcodes']):
                        print(f'UPDATING CATCODES: categorical field - {x}')
                        encoder['catcodes'][x] = {}
                        encoder['currentcode'] += 1
                        print(f'UPDATING CATCODES: categorical value for field {x} - {datarow[x]}')
                        encoder['catcodes'][x][datarow[x]] = encoder['currentcode']  # encoding the feature
                    elif(datarow[x] not in encoder['catcodes'][x]):
                        encoder['currentcode'] += 1
                        print(f'UPDATING CATCODES: categorical value for field {x} - {datarow[x]}')
                        encoder['catcodes'][x][datarow[x]] = encoder['currentcode']  # encoding the feature

                    code = encoder['catcodes'][x][datarow[x]]
                    datastring = datastring + " "+str(i)+":" + str(int(code))+":1"

            datastring += '\n'
            text_file.write(datastring)
    return encoder

# %%
good_columns = [
    'zone_id',
    'banner_id',
    'campaign_clicks',
    'os_id',
    'country_id',
    'impressions',
    'clicks',
    'oaid_hash'
]
df = df[[*good_columns, 'date_time']]

# %%
def feature_prepare(df: pd.DataFrame, rules) -> pd.DataFrame:
    for name, count in rules:
        mask = df[name].map(df[name].value_counts()) < count
        df[name] = df[name].mask(mask, -1)
    return df

# %%
df = feature_prepare(df, [
    ('oaid_hash', int(np.percentile(df.oaid_hash.value_counts(), 75))), 
    ('banner_id', int(np.percentile(df.banner_id.value_counts(), 80))),
    ('zone_id', int(np.percentile(df.zone_id.value_counts(), 90)))
])

# %%
target = 'clicks'
num_features = ['campaign_clicks']
cat_features = [feature for feature in good_columns if (feature!='campaign_clicks') and (feature != 'clicks') and (feature != 'date_time')]

# %%
test_df = df[df['date_time'] >= '2021-10-02'].drop(['date_time'], axis=1)
train_df = df[df['date_time'] < '2021-10-02'].drop(['date_time'], axis=1)

# %%
np.save('true.npy', np.array(test_df['clicks']))

# %%
encoder = {
    'currentcode': 1,
    'catdict': {},
    'catcodes': {}
}

encoder = _convert_to_ffm('data/', train_df, 'train', target,
                          num_features,
                          cat_features,
                          good_columns,
                          encoder)

encoder = _convert_to_ffm('data/', test_df, 'test', target,
                          num_features,
                          cat_features,
                          good_columns,
                          encoder)
# Out:
# convert_to_ffm - START
# UPDATING CATDICT: numeric field - campaign_clicks
# UPDATING CATDICT: categorical field - zone_id
# UPDATING CATDICT: categorical field - banner_id
# UPDATING CATDICT: categorical field - os_id
# UPDATING CATDICT: categorical field - country_id
# UPDATING CATDICT: categorical field - impressions
# UPDATING CATDICT: categorical field - oaid_hash
# UPDATING CATCODES: categorical field - zone_id
# UPDATING CATCODES: categorical value for field zone_id - 0
# UPDATING CATCODES: categorical field - banner_id
# UPDATING CATCODES: categorical value for field banner_id - 0
# UPDATING CATCODES: categorical field - os_id
# UPDATING CATCODES: categorical value for field os_id - 0
# UPDATING CATCODES: categorical field - country_id
# UPDATING CATCODES: categorical value for field country_id - 0
# UPDATING CATCODES: categorical field - impressions
# UPDATING CATCODES: categorical value for field impressions - 1
# UPDATING CATCODES: categorical field - oaid_hash
# UPDATING CATCODES: categorical value for field oaid_hash - -1
# UPDATING CATCODES: categorical value for field zone_id - 1
# UPDATING CATCODES: categorical value for field banner_id - -1
# UPDATING CATCODES: categorical value for field country_id - 1
# UPDATING CATCODES: categorical value for field zone_id - 2
# UPDATING CATCODES: categorical value for field banner_id - 2
# UPDATING CATCODES: categorical value for field zone_id - 3
# UPDATING CATCODES: categorical value for field banner_id - 3
# UPDATING CATCODES: categorical value for field os_id - 1
# UPDATING CATCODES: categorical value for field zone_id - -1
# UPDATING CATCODES: categorical value for field os_id - 2
# UPDATING CATCODES: categorical value for field country_id - 2
# UPDATING CATCODES: categorical value for field banner_id - 6
# UPDATING CATCODES: categorical value for field os_id - 3
# UPDATING CATCODES: categorical value for field banner_id - 7
# UPDATING CATCODES: categorical value for field os_id - 4
# UPDATING CATCODES: categorical value for field zone_id - 8
# UPDATING CATCODES: categorical value for field country_id - 3
# UPDATING CATCODES: categorical value for field country_id - 4
# UPDATING CATCODES: categorical value for field zone_id - 11
# UPDATING CATCODES: categorical value for field country_id - 5
# UPDATING CATCODES: categorical value for field zone_id - 12
# UPDATING CATCODES: categorical value for field zone_id - 13
# UPDATING CATCODES: categorical value for field zone_id - 14
# UPDATING CATCODES: categorical value for field banner_id - 16
# UPDATING CATCODES: categorical value for field zone_id - 15
# UPDATING CATCODES: categorical value for field country_id - 6
# UPDATING CATCODES: categorical value for field zone_id - 16
# UPDATING CATCODES: categorical value for field banner_id - 18
# UPDATING CATCODES: categorical value for field zone_id - 17
# UPDATING CATCODES: categorical value for field zone_id - 18
# UPDATING CATCODES: categorical value for field zone_id - 19
# UPDATING CATCODES: categorical value for field banner_id - 21
# UPDATING CATCODES: categorical value for field banner_id - 22
# UPDATING CATCODES: categorical value for field country_id - 7
# UPDATING CATCODES: categorical value for field banner_id - 23
# UPDATING CATCODES: categorical value for field country_id - 8
# UPDATING CATCODES: categorical value for field zone_id - 20
# UPDATING CATCODES: categorical value for field zone_id - 21
# UPDATING CATCODES: categorical value for field os_id - 5
# UPDATING CATCODES: categorical value for field country_id - 9
# UPDATING CATCODES: categorical value for field zone_id - 24
# UPDATING CATCODES: categorical value for field banner_id - 28
# UPDATING CATCODES: categorical value for field banner_id - 29
# UPDATING CATCODES: categorical value for field country_id - 10
# UPDATING CATCODES: categorical value for field zone_id - 27
# UPDATING CATCODES: categorical value for field os_id - 6
# UPDATING CATCODES: categorical value for field zone_id - 30
# UPDATING CATCODES: categorical value for field banner_id - 39
# UPDATING CATCODES: categorical value for field zone_id - 31
# UPDATING CATCODES: categorical value for field country_id - 11
# UPDATING CATCODES: categorical value for field banner_id - 46
# UPDATING CATCODES: categorical value for field country_id - 12
# UPDATING CATCODES: categorical value for field banner_id - 49
# UPDATING CATCODES: categorical value for field banner_id - 52
# UPDATING CATCODES: categorical value for field zone_id - 38
# UPDATING CATCODES: categorical value for field zone_id - 41
# UPDATING CATCODES: categorical value for field banner_id - 59
# UPDATING CATCODES: categorical value for field banner_id - 65
# UPDATING CATCODES: categorical value for field banner_id - 67
# UPDATING CATCODES: categorical value for field zone_id - 45
# UPDATING CATCODES: categorical value for field country_id - 13
# UPDATING CATCODES: categorical value for field zone_id - 49
# UPDATING CATCODES: categorical value for field oaid_hash - 2770691217625752460
# UPDATING CATCODES: categorical value for field zone_id - 50
# UPDATING CATCODES: categorical value for field zone_id - 52
# UPDATING CATCODES: categorical value for field zone_id - 54
# UPDATING CATCODES: categorical value for field banner_id - 84
# UPDATING CATCODES: categorical value for field banner_id - 91
# UPDATING CATCODES: categorical value for field banner_id - 92
# UPDATING CATCODES: categorical value for field banner_id - 97
# UPDATING CATCODES: categorical value for field country_id - 14
# UPDATING CATCODES: categorical value for field zone_id - 79
# UPDATING CATCODES: categorical value for field country_id - 15
# UPDATING CATCODES: categorical value for field country_id - 16
# UPDATING CATCODES: categorical value for field banner_id - 167
# UPDATING CATCODES: categorical value for field banner_id - 180
# UPDATING CATCODES: categorical value for field banner_id - 188
# UPDATING CATCODES: categorical value for field oaid_hash - 6399916462685026413
# UPDATING CATCODES: categorical value for field zone_id - 133
# UPDATING CATCODES: categorical value for field oaid_hash - 1561687382219885635
# UPDATING CATCODES: categorical value for field oaid_hash - 3428899075717665322
# UPDATING CATCODES: categorical value for field zone_id - 185
# UPDATING CATCODES: categorical value for field oaid_hash - 2793608812473792543
# UPDATING CATCODES: categorical value for field banner_id - 361
# UPDATING CATCODES: categorical value for field oaid_hash - 5921498747537594849
# UPDATING CATCODES: categorical value for field banner_id - 403
# UPDATING CATCODES: categorical value for field zone_id - 216
# UPDATING CATCODES: categorical value for field oaid_hash - 6693504374571799715
# UPDATING CATCODES: categorical value for field oaid_hash - 244417163782379970
# UPDATING CATCODES: categorical value for field oaid_hash - 4953567779428125396
# UPDATING CATCODES: categorical value for field oaid_hash - 5307571657906926956
# UPDATING CATCODES: categorical value for field oaid_hash - 847681182969060215
# UPDATING CATCODES: categorical value for field oaid_hash - 2932475828475335271
# UPDATING CATCODES: categorical value for field oaid_hash - 1042938738746139826
# UPDATING CATCODES: categorical value for field banner_id - 517
# UPDATING CATCODES: categorical value for field oaid_hash - 1337055020511068033
# UPDATING CATCODES: categorical value for field zone_id - 309
# UPDATING CATCODES: categorical value for field oaid_hash - 4479517017429980753
# UPDATING CATCODES: categorical value for field oaid_hash - 7404341369972501966
# UPDATING CATCODES: categorical value for field oaid_hash - 7640875311084540729
# UPDATING CATCODES: categorical value for field banner_id - 596
# UPDATING CATCODES: categorical value for field banner_id - 609
# UPDATING CATCODES: categorical value for field oaid_hash - 5375922963018560980
# UPDATING CATCODES: categorical value for field oaid_hash - 5824388690493434905
# UPDATING CATCODES: categorical value for field oaid_hash - 5448366692130646884
# UPDATING CATCODES: categorical value for field oaid_hash - 6811841836522502025
# UPDATING CATCODES: categorical value for field oaid_hash - 6729096861026366188
# UPDATING CATCODES: categorical value for field oaid_hash - 6902707858736137380
# UPDATING CATCODES: categorical value for field banner_id - 671
# UPDATING CATCODES: categorical value for field oaid_hash - 8032047879918222523
# UPDATING CATCODES: categorical value for field oaid_hash - 2723249790577191188
# UPDATING CATCODES: categorical value for field oaid_hash - 3443481738804143922
# UPDATING CATCODES: categorical value for field oaid_hash - 3680349959775161181
# UPDATING CATCODES: categorical value for field oaid_hash - 5522954143968446342
# UPDATING CATCODES: categorical value for field oaid_hash - 3354612649540968810
# UPDATING CATCODES: categorical value for field oaid_hash - 287070909624614747
# UPDATING CATCODES: categorical value for field oaid_hash - 4882457832362949033
# UPDATING CATCODES: categorical value for field oaid_hash - 3826213987559901507
# UPDATING CATCODES: categorical value for field os_id - 7
# UPDATING CATCODES: categorical value for field oaid_hash - 972317677657366055
# UPDATING CATCODES: categorical value for field oaid_hash - 6281239119278787386
# UPDATING CATCODES: categorical value for field oaid_hash - 4995445639763870787
# UPDATING CATCODES: categorical value for field oaid_hash - 3197340394554347254
# UPDATING CATCODES: categorical value for field oaid_hash - 5351436589773950064
# UPDATING CATCODES: categorical value for field banner_id - 762
# UPDATING CATCODES: categorical value for field oaid_hash - 4913983047583624636
# UPDATING CATCODES: categorical value for field zone_id - 433
# UPDATING CATCODES: categorical value for field oaid_hash - 3813511895020377829
# UPDATING CATCODES: categorical value for field oaid_hash - 5632559262123767562
# UPDATING CATCODES: categorical value for field oaid_hash - 8812981574489858646
# UPDATING CATCODES: categorical value for field oaid_hash - 6435461002209803744
# UPDATING CATCODES: categorical value for field oaid_hash - 5023283936586308615
# UPDATING CATCODES: categorical value for field zone_id - 485
# UPDATING CATCODES: categorical value for field oaid_hash - 4566287088198084271
# UPDATING CATCODES: categorical value for field oaid_hash - 6971720873739197298
# UPDATING CATCODES: categorical value for field oaid_hash - 6656367941860758746
# UPDATING CATCODES: categorical value for field oaid_hash - 694635178565430516
# UPDATING CATCODES: categorical value for field oaid_hash - 322873776000025657
# UPDATING CATCODES: categorical value for field oaid_hash - 5480303832133635738
# UPDATING CATCODES: categorical value for field oaid_hash - 8829311456791328734
# UPDATING CATCODES: categorical value for field os_id - 8
# UPDATING CATCODES: categorical value for field oaid_hash - 7963082434340158238
# UPDATING CATCODES: categorical value for field oaid_hash - 5745321980300475217
# UPDATING CATCODES: categorical value for field oaid_hash - 1818824538629848025
# UPDATING CATCODES: categorical value for field oaid_hash - 1522925564402828277
# UPDATING CATCODES: categorical value for field oaid_hash - 285006361890209430
# UPDATING CATCODES: categorical value for field oaid_hash - 5883034110951014560
# UPDATING CATCODES: categorical value for field oaid_hash - 8225279539445635923
# UPDATING CATCODES: categorical value for field oaid_hash - 5416788382682066887
# UPDATING CATCODES: categorical value for field oaid_hash - 313592488392374701
# UPDATING CATCODES: categorical value for field oaid_hash - 542178956254926560
# UPDATING CATCODES: categorical value for field oaid_hash - 3055908068054435716
# UPDATING CATCODES: categorical value for field oaid_hash - 3254191445287183615
# UPDATING CATCODES: categorical value for field oaid_hash - 5883602580787324792
# UPDATING CATCODES: categorical value for field oaid_hash - 424500590733511197
# UPDATING CATCODES: categorical value for field oaid_hash - 1473296316605129800
# UPDATING CATCODES: categorical value for field oaid_hash - 3441119544705989616
# UPDATING CATCODES: categorical value for field oaid_hash - 6420834263322299712
# UPDATING CATCODES: categorical value for field oaid_hash - 1845880287830457701
# UPDATING CATCODES: categorical value for field oaid_hash - 5372356545446343769
# UPDATING CATCODES: categorical value for field oaid_hash - 6807818707599118251
# UPDATING CATCODES: categorical value for field oaid_hash - 3495098638031251105
# UPDATING CATCODES: categorical value for field oaid_hash - 1919848089815513327
# UPDATING CATCODES: categorical value for field oaid_hash - 6420781514325377964
# UPDATING CATCODES: categorical value for field oaid_hash - 3547476413292418291
# UPDATING CATCODES: categorical value for field oaid_hash - 4414033950359624848
# UPDATING CATCODES: categorical value for field oaid_hash - 50818815081843553
# UPDATING CATCODES: categorical value for field oaid_hash - 2271520901434241997
# UPDATING CATCODES: categorical value for field oaid_hash - 7789742083260456954
# UPDATING CATCODES: categorical value for field oaid_hash - 5794407207106236930
# UPDATING CATCODES: categorical value for field oaid_hash - 6948624593522210897
# UPDATING CATCODES: categorical value for field oaid_hash - 183956482273867701
# UPDATING CATCODES: categorical value for field oaid_hash - 493916096596890035
# UPDATING CATCODES: categorical value for field oaid_hash - 6520186304875159375
# UPDATING CATCODES: categorical value for field oaid_hash - 220917523519234846
# UPDATING CATCODES: categorical value for field oaid_hash - 3711488294213586979
# UPDATING CATCODES: categorical value for field oaid_hash - 81537612512026983
# UPDATING CATCODES: categorical value for field oaid_hash - 3597231651303145347
# UPDATING CATCODES: categorical value for field oaid_hash - 7440099349383890988
# UPDATING CATCODES: categorical value for field oaid_hash - 5694892096476252243
# UPDATING CATCODES: categorical value for field oaid_hash - 533552375446911051
# UPDATING CATCODES: categorical value for field oaid_hash - 5708671964518374334
# UPDATING CATCODES: categorical value for field oaid_hash - 7519222298138348213
# UPDATING CATCODES: categorical value for field oaid_hash - 3423538144278210424
# UPDATING CATCODES: categorical value for field oaid_hash - 9147167173199190030
# UPDATING CATCODES: categorical value for field oaid_hash - 6507784222720528365
# UPDATING CATCODES: categorical value for field oaid_hash - 2158010307707273890
# UPDATING CATCODES: categorical value for field oaid_hash - 6975134783872425954
# UPDATING CATCODES: categorical value for field oaid_hash - 6536242342922193306
# UPDATING CATCODES: categorical value for field oaid_hash - 4479268932895378525
# UPDATING CATCODES: categorical value for field oaid_hash - 1216097312048789046
# UPDATING CATCODES: categorical value for field oaid_hash - 1088840670478471566
# UPDATING CATCODES: categorical value for field oaid_hash - 9023473366293533770
# UPDATING CATCODES: categorical value for field oaid_hash - 7826334681338041925
# UPDATING CATCODES: categorical value for field oaid_hash - 1703311103676756722
# UPDATING CATCODES: categorical value for field oaid_hash - 3415886143771611723
# UPDATING CATCODES: categorical value for field oaid_hash - 1778226057509157378
# UPDATING CATCODES: categorical value for field oaid_hash - 574836521771367017
# UPDATING CATCODES: categorical value for field oaid_hash - 4415150764477036758
# UPDATING CATCODES: categorical value for field oaid_hash - 5710584128585568405
# UPDATING CATCODES: categorical value for field oaid_hash - 4056257729306555783
# UPDATING CATCODES: categorical value for field oaid_hash - 1693655576099899247
# UPDATING CATCODES: categorical value for field oaid_hash - 4961024174670368904
# UPDATING CATCODES: categorical value for field oaid_hash - 2807791641740382566
# UPDATING CATCODES: categorical value for field oaid_hash - 8266399773473667124
# UPDATING CATCODES: categorical value for field oaid_hash - 294467222334883323
# UPDATING CATCODES: categorical value for field oaid_hash - 463172681090821798
# UPDATING CATCODES: categorical value for field oaid_hash - 4075621584403940488
# UPDATING CATCODES: categorical value for field oaid_hash - 5450923547073052789
# UPDATING CATCODES: categorical value for field oaid_hash - 4234242022215769053
# UPDATING CATCODES: categorical value for field oaid_hash - 2510240921981404817
# UPDATING CATCODES: categorical value for field oaid_hash - 1196542931016942753
# UPDATING CATCODES: categorical value for field oaid_hash - 3550917059983925366
# UPDATING CATCODES: categorical value for field oaid_hash - 3577527284690477778
# UPDATING CATCODES: categorical value for field oaid_hash - 6620977557515458859
# UPDATING CATCODES: categorical value for field oaid_hash - 7524873262758336249
# UPDATING CATCODES: categorical value for field oaid_hash - 405312015898789173
# UPDATING CATCODES: categorical value for field oaid_hash - 2513293836930434993
# UPDATING CATCODES: categorical value for field oaid_hash - 1142003880540328727
# UPDATING CATCODES: categorical value for field oaid_hash - 5387776193573817497
# UPDATING CATCODES: categorical value for field oaid_hash - 8643230964272366646
# UPDATING CATCODES: categorical value for field oaid_hash - 3249707210889861989
# UPDATING CATCODES: categorical value for field oaid_hash - 1174374597128820528
# UPDATING CATCODES: categorical value for field oaid_hash - 7006378580775407747
# UPDATING CATCODES: categorical value for field oaid_hash - 7711800443439145115
# UPDATING CATCODES: categorical value for field oaid_hash - 4577408917020591949
# UPDATING CATCODES: categorical value for field oaid_hash - 4776946477878230855
# UPDATING CATCODES: categorical value for field oaid_hash - 1344133003877088572
# UPDATING CATCODES: categorical value for field oaid_hash - 3768650544931667276
# UPDATING CATCODES: categorical value for field oaid_hash - 1733314009195517029
# UPDATING CATCODES: categorical value for field oaid_hash - 2016336998165050001
# UPDATING CATCODES: categorical value for field oaid_hash - 462829502957740138
# UPDATING CATCODES: categorical value for field oaid_hash - 8463435137854354886
# UPDATING CATCODES: categorical value for field oaid_hash - 6412610856407708749
# UPDATING CATCODES: categorical value for field oaid_hash - 4260854707427443920
# UPDATING CATCODES: categorical value for field oaid_hash - 6685460598812035115
# UPDATING CATCODES: categorical value for field oaid_hash - 1249697116601243724
# UPDATING CATCODES: categorical value for field oaid_hash - 8172689480629424756
# UPDATING CATCODES: categorical value for field oaid_hash - 4138434915732793141
# UPDATING CATCODES: categorical value for field oaid_hash - 3095416717990202189
# UPDATING CATCODES: categorical value for field oaid_hash - 2062926429307639922
# UPDATING CATCODES: categorical value for field oaid_hash - 6633591298167935743
# UPDATING CATCODES: categorical value for field oaid_hash - 7789772837187963258
# UPDATING CATCODES: categorical value for field oaid_hash - 6426067088702089179
# UPDATING CATCODES: categorical value for field oaid_hash - 8212598110927942749
# UPDATING CATCODES: categorical value for field oaid_hash - 1271780233350703038
# UPDATING CATCODES: categorical value for field oaid_hash - 207914950857395960
# UPDATING CATCODES: categorical value for field oaid_hash - 3831243334982104269
# UPDATING CATCODES: categorical value for field oaid_hash - 7702350949760599171
# UPDATING CATCODES: categorical value for field oaid_hash - 1376158388227012721
# UPDATING CATCODES: categorical value for field oaid_hash - 3138421694887558879
# UPDATING CATCODES: categorical value for field oaid_hash - 6606826594216095046
# UPDATING CATCODES: categorical value for field oaid_hash - 8002093255707391529
# UPDATING CATCODES: categorical value for field oaid_hash - 3663290957072023428
# UPDATING CATCODES: categorical value for field oaid_hash - 5228332191626575959
# UPDATING CATCODES: categorical value for field oaid_hash - 7692659248669893558
# UPDATING CATCODES: categorical value for field oaid_hash - 6702493379600406505
# UPDATING CATCODES: categorical value for field oaid_hash - 5430980666194897152
# UPDATING CATCODES: categorical value for field oaid_hash - 3961781386482255370
# UPDATING CATCODES: categorical value for field oaid_hash - 846925516501953375
# UPDATING CATCODES: categorical value for field oaid_hash - 4869203990843104412
# UPDATING CATCODES: categorical value for field oaid_hash - 3252153561459293586
# UPDATING CATCODES: categorical value for field oaid_hash - 8831967789188395298
# UPDATING CATCODES: categorical value for field oaid_hash - 6404000549859667721
# UPDATING CATCODES: categorical value for field oaid_hash - 6561649215937570754
# UPDATING CATCODES: categorical value for field oaid_hash - 7692771892793086292
# UPDATING CATCODES: categorical value for field oaid_hash - 1939791379053496779
# UPDATING CATCODES: categorical value for field oaid_hash - 2956779837023033175
# UPDATING CATCODES: categorical value for field oaid_hash - 3908975528449503115
# UPDATING CATCODES: categorical value for field oaid_hash - 1945743026081421648
# UPDATING CATCODES: categorical value for field oaid_hash - 5336376657103139358
# UPDATING CATCODES: categorical value for field oaid_hash - 2135301703665005655
# UPDATING CATCODES: categorical value for field oaid_hash - 8801338684219989324
# UPDATING CATCODES: categorical value for field oaid_hash - 477587782114523017
# UPDATING CATCODES: categorical value for field oaid_hash - 3136192793299330509
# UPDATING CATCODES: categorical value for field oaid_hash - 3847880657798351903
# UPDATING CATCODES: categorical value for field oaid_hash - 6016319681149335790
# UPDATING CATCODES: categorical value for field oaid_hash - 4297376831832854505
# UPDATING CATCODES: categorical value for field oaid_hash - 5474312847287355085
# UPDATING CATCODES: categorical value for field oaid_hash - 2435647944688198184
# UPDATING CATCODES: categorical value for field oaid_hash - 9194525830892011652
# UPDATING CATCODES: categorical value for field oaid_hash - 915853360102928634
# UPDATING CATCODES: categorical value for field oaid_hash - 2183310268374456275
# UPDATING CATCODES: categorical value for field oaid_hash - 5202092095133965415
# UPDATING CATCODES: categorical value for field oaid_hash - 8690400886115874846
# UPDATING CATCODES: categorical value for field oaid_hash - 2081750384780135904
# UPDATING CATCODES: categorical value for field oaid_hash - 7604097649788447887
# UPDATING CATCODES: categorical value for field oaid_hash - 8698398089350679291
# UPDATING CATCODES: categorical value for field oaid_hash - 1313622444974428444
# UPDATING CATCODES: categorical value for field oaid_hash - 8087516956710438953
# UPDATING CATCODES: categorical value for field oaid_hash - 5114037629981500557
# UPDATING CATCODES: categorical value for field oaid_hash - 1709452979222046992
# UPDATING CATCODES: categorical value for field oaid_hash - 5991804232410509149
# UPDATING CATCODES: categorical value for field oaid_hash - 5653492082082676575
# UPDATING CATCODES: categorical value for field oaid_hash - 1981926701212817517
# UPDATING CATCODES: categorical value for field oaid_hash - 82242873134894893
# UPDATING CATCODES: categorical value for field oaid_hash - 2018177127793747347
# UPDATING CATCODES: categorical value for field oaid_hash - 4691038895768836
# UPDATING CATCODES: categorical value for field oaid_hash - 8841927762837734573
# UPDATING CATCODES: categorical value for field oaid_hash - 4137596588159584647
# UPDATING CATCODES: categorical value for field oaid_hash - 3573083475888247401
# UPDATING CATCODES: categorical value for field oaid_hash - 1883290491777415020
# UPDATING CATCODES: categorical value for field oaid_hash - 4623626627148459137
# UPDATING CATCODES: categorical value for field oaid_hash - 1654731561315709300
# UPDATING CATCODES: categorical value for field oaid_hash - 68032495675518021
# UPDATING CATCODES: categorical value for field oaid_hash - 7528724720932469707
# UPDATING CATCODES: categorical value for field oaid_hash - 8713770981210933692
# UPDATING CATCODES: categorical value for field oaid_hash - 2919999217797957123
# UPDATING CATCODES: categorical value for field oaid_hash - 6657067905302378312
# UPDATING CATCODES: categorical value for field oaid_hash - 7059078158465945856
# UPDATING CATCODES: categorical value for field oaid_hash - 8299863284302338659
# UPDATING CATCODES: categorical value for field oaid_hash - 8232394572510757439
# UPDATING CATCODES: categorical value for field oaid_hash - 7823751591356182056
# UPDATING CATCODES: categorical value for field oaid_hash - 2052859648723799180
# UPDATING CATCODES: categorical value for field oaid_hash - 7174213654976893909
# UPDATING CATCODES: categorical value for field oaid_hash - 5986185046309281996
# UPDATING CATCODES: categorical value for field oaid_hash - 5429151888564015468
# UPDATING CATCODES: categorical value for field oaid_hash - 6675419731653588532
# UPDATING CATCODES: categorical value for field oaid_hash - 834719006126710195
# UPDATING CATCODES: categorical value for field oaid_hash - 600026397521020665
# UPDATING CATCODES: categorical value for field oaid_hash - 114631960517560509
# UPDATING CATCODES: categorical value for field oaid_hash - 1913860484492393488
# UPDATING CATCODES: categorical value for field oaid_hash - 7198875224987665244
# UPDATING CATCODES: categorical value for field oaid_hash - 5194569927001216417
# UPDATING CATCODES: categorical value for field oaid_hash - 6574190506797180335
# UPDATING CATCODES: categorical value for field oaid_hash - 3517544510565085465
# UPDATING CATCODES: categorical value for field oaid_hash - 5973264706983239258
# UPDATING CATCODES: categorical value for field oaid_hash - 171178432041620512
# UPDATING CATCODES: categorical value for field oaid_hash - 8116879314568007045
# UPDATING CATCODES: categorical value for field oaid_hash - 7749700942332224657
# UPDATING CATCODES: categorical value for field oaid_hash - 5567771039949182762
# UPDATING CATCODES: categorical value for field oaid_hash - 3845793820964985993
# UPDATING CATCODES: categorical value for field oaid_hash - 7145421494689319769
# UPDATING CATCODES: categorical value for field oaid_hash - 5921034806370841283
# UPDATING CATCODES: categorical value for field oaid_hash - 7699859695061718767
# UPDATING CATCODES: categorical value for field oaid_hash - 5329212593085883375
# UPDATING CATCODES: categorical value for field oaid_hash - 9015951821784273289
# UPDATING CATCODES: categorical value for field oaid_hash - 195702349544205547
# UPDATING CATCODES: categorical value for field oaid_hash - 4462008182547888333
# UPDATING CATCODES: categorical value for field oaid_hash - 5778915496328945048
# UPDATING CATCODES: categorical value for field oaid_hash - 6423391412590140783
# UPDATING CATCODES: categorical value for field oaid_hash - 7015602254242441249
# UPDATING CATCODES: categorical value for field oaid_hash - 4504694588638610238
# UPDATING CATCODES: categorical value for field oaid_hash - 3246010961384276187
# UPDATING CATCODES: categorical value for field oaid_hash - 4386997287599735408
# UPDATING CATCODES: categorical value for field oaid_hash - 6946821200105329931
# UPDATING CATCODES: categorical value for field oaid_hash - 2856922580711775680
# UPDATING CATCODES: categorical value for field oaid_hash - 5169522994178501827
# UPDATING CATCODES: categorical value for field oaid_hash - 6039017559552095387
# UPDATING CATCODES: categorical value for field oaid_hash - 4133016155011971325
# UPDATING CATCODES: categorical value for field oaid_hash - 7955051168031699445
# UPDATING CATCODES: categorical value for field oaid_hash - 5368112142028160958
# UPDATING CATCODES: categorical value for field oaid_hash - 4031033028741490661
# UPDATING CATCODES: categorical value for field oaid_hash - 2094212391637202739
# UPDATING CATCODES: categorical value for field oaid_hash - 1291051284292591020
# UPDATING CATCODES: categorical value for field oaid_hash - 3909283290949736470
# UPDATING CATCODES: categorical value for field oaid_hash - 8328437872634209580
# UPDATING CATCODES: categorical value for field oaid_hash - 8318707549733186380
# UPDATING CATCODES: categorical value for field banner_id - 1233
# UPDATING CATCODES: categorical value for field banner_id - 1234
# UPDATING CATCODES: categorical value for field oaid_hash - 3777281828958054590
# UPDATING CATCODES: categorical value for field banner_id - 1236
# UPDATING CATCODES: categorical value for field banner_id - 1237
# UPDATING CATCODES: categorical value for field oaid_hash - 3618234116617733528
# UPDATING CATCODES: categorical value for field oaid_hash - 1828432138997132789
# UPDATING CATCODES: categorical value for field banner_id - 1235
# UPDATING CATCODES: categorical value for field banner_id - 1238
# UPDATING CATCODES: categorical value for field banner_id - 1239
# UPDATING CATCODES: categorical value for field oaid_hash - 689701500704617484
# UPDATING CATCODES: categorical value for field banner_id - 1240
# UPDATING CATCODES: categorical value for field oaid_hash - 806346363853481600
# UPDATING CATCODES: categorical value for field oaid_hash - 6489710048633664413
# UPDATING CATCODES: categorical value for field oaid_hash - 2324455519458487522
# UPDATING CATCODES: categorical value for field oaid_hash - 8756041682328931056
# UPDATING CATCODES: categorical value for field oaid_hash - 2285649389437022583
# UPDATING CATCODES: categorical value for field oaid_hash - 7778402214309164700
# UPDATING CATCODES: categorical value for field oaid_hash - 7815703191656658352
# UPDATING CATCODES: categorical value for field oaid_hash - 3140665891768039243
# UPDATING CATCODES: categorical value for field oaid_hash - 3375698397737628939
# UPDATING CATCODES: categorical value for field oaid_hash - 5350463203073246794
# UPDATING CATCODES: categorical value for field oaid_hash - 7390197570768138769
# UPDATING CATCODES: categorical value for field oaid_hash - 677657829626114721
# UPDATING CATCODES: categorical value for field oaid_hash - 7868945106070326182
# UPDATING CATCODES: categorical value for field oaid_hash - 5517847099450203000
# UPDATING CATCODES: categorical value for field oaid_hash - 5695075849565988006
# UPDATING CATCODES: categorical value for field oaid_hash - 7548796390289982948
# UPDATING CATCODES: categorical value for field oaid_hash - 3336956940316169013
# UPDATING CATCODES: categorical value for field oaid_hash - 6690221513377160838
# UPDATING CATCODES: categorical value for field oaid_hash - 4907977781994636301
# UPDATING CATCODES: categorical value for field oaid_hash - 5690653745509628214
# UPDATING CATCODES: categorical value for field oaid_hash - 8745382090259366512
# UPDATING CATCODES: categorical value for field oaid_hash - 1833987781926735246
# UPDATING CATCODES: categorical value for field oaid_hash - 308174966294367527
# UPDATING CATCODES: categorical value for field oaid_hash - 8477871151192559219
# UPDATING CATCODES: categorical value for field oaid_hash - 4753020849865051428
# UPDATING CATCODES: categorical value for field oaid_hash - 5627140277306024975
# UPDATING CATCODES: categorical value for field oaid_hash - 6981547155777007591
# UPDATING CATCODES: categorical value for field oaid_hash - 5823401709201419845
# UPDATING CATCODES: categorical value for field oaid_hash - 5964106911370193425
# UPDATING CATCODES: categorical value for field oaid_hash - 6455190059922576462
# UPDATING CATCODES: categorical value for field oaid_hash - 3168585828438802535
# UPDATING CATCODES: categorical value for field oaid_hash - 8891999696921924469
# UPDATING CATCODES: categorical value for field oaid_hash - 1944563923400542501
# UPDATING CATCODES: categorical value for field oaid_hash - 3012920032556544932
# UPDATING CATCODES: categorical value for field oaid_hash - 342915336262442551
# UPDATING CATCODES: categorical value for field oaid_hash - 212489647466209901
# UPDATING CATCODES: categorical value for field oaid_hash - 5298558651584720748
# UPDATING CATCODES: categorical value for field oaid_hash - 8172746631787731041
# UPDATING CATCODES: categorical value for field oaid_hash - 7903741466709806307
# UPDATING CATCODES: categorical value for field oaid_hash - 4670219371711423017
# UPDATING CATCODES: categorical value for field oaid_hash - 6721494003227810471
# UPDATING CATCODES: categorical value for field oaid_hash - 8896868712752526966
# UPDATING CATCODES: categorical value for field oaid_hash - 6634992547576940934
# UPDATING CATCODES: categorical value for field oaid_hash - 4913247509419123947
# UPDATING CATCODES: categorical value for field oaid_hash - 7588928271610009382
# UPDATING CATCODES: categorical value for field oaid_hash - 8972259475933241737
# UPDATING CATCODES: categorical value for field oaid_hash - 6292101186909373324
# UPDATING CATCODES: categorical value for field oaid_hash - 6560632185704178586
# UPDATING CATCODES: categorical value for field oaid_hash - 8139921669423779213
# UPDATING CATCODES: categorical value for field oaid_hash - 2791984960260377804
# UPDATING CATCODES: categorical value for field oaid_hash - 6381895281164870616
# UPDATING CATCODES: categorical value for field oaid_hash - 6278463989862043121
# UPDATING CATCODES: categorical value for field oaid_hash - 2987518762006314514
# UPDATING CATCODES: categorical value for field oaid_hash - 4313427064791186697
# UPDATING CATCODES: categorical value for field oaid_hash - 880204042219527743
# UPDATING CATCODES: categorical value for field oaid_hash - 8990577097271127
# UPDATING CATCODES: categorical value for field oaid_hash - 8926104542609530835
# UPDATING CATCODES: categorical value for field oaid_hash - 6592377298442942245
# UPDATING CATCODES: categorical value for field oaid_hash - 1162806121002679366
# UPDATING CATCODES: categorical value for field oaid_hash - 6628483425554388677
# UPDATING CATCODES: categorical value for field oaid_hash - 3588138226806259679
# UPDATING CATCODES: categorical value for field oaid_hash - 7769248001919139238
# UPDATING CATCODES: categorical value for field oaid_hash - 538809503005260153
# UPDATING CATCODES: categorical value for field oaid_hash - 4083602129802376788
# UPDATING CATCODES: categorical value for field oaid_hash - 1652688547299375460
# UPDATING CATCODES: categorical value for field oaid_hash - 300938052719102147
# UPDATING CATCODES: categorical value for field oaid_hash - 6614983692251202914
# UPDATING CATCODES: categorical value for field oaid_hash - 2375760285606557912
# UPDATING CATCODES: categorical value for field oaid_hash - 3477394810443536929
# UPDATING CATCODES: categorical value for field oaid_hash - 9096266380877146554
# UPDATING CATCODES: categorical value for field oaid_hash - 7145064114878242281
# UPDATING CATCODES: categorical value for field oaid_hash - 9031977595849042358
# UPDATING CATCODES: categorical value for field oaid_hash - 7068220236544935620
# UPDATING CATCODES: categorical value for field oaid_hash - 5131378922176271877
# UPDATING CATCODES: categorical value for field oaid_hash - 5702589771366739720
# UPDATING CATCODES: categorical value for field oaid_hash - 3168927753371951114
# UPDATING CATCODES: categorical value for field oaid_hash - 1853083484010518191
# UPDATING CATCODES: categorical value for field oaid_hash - 4699381085132656219
# UPDATING CATCODES: categorical value for field oaid_hash - 4471770358015522303
# UPDATING CATCODES: categorical value for field oaid_hash - 324595206116710282
# UPDATING CATCODES: categorical value for field oaid_hash - 1921991733196495262
# UPDATING CATCODES: categorical value for field oaid_hash - 7368020748352834387
# UPDATING CATCODES: categorical value for field oaid_hash - 777813202827899938
# UPDATING CATCODES: categorical value for field oaid_hash - 3560340907211074936
# UPDATING CATCODES: categorical value for field oaid_hash - 1499319146049968958
# UPDATING CATCODES: categorical value for field oaid_hash - 3666060003713728256
# UPDATING CATCODES: categorical value for field oaid_hash - 3764257162291603143
# UPDATING CATCODES: categorical value for field oaid_hash - 743630346660569924
# UPDATING CATCODES: categorical value for field oaid_hash - 6274362223259238559
# UPDATING CATCODES: categorical value for field oaid_hash - 8569204395309783077
# UPDATING CATCODES: categorical value for field oaid_hash - 5757403252993355027
# UPDATING CATCODES: categorical value for field oaid_hash - 6229996401945844380
# UPDATING CATCODES: categorical value for field oaid_hash - 3304038514535007791
# UPDATING CATCODES: categorical value for field oaid_hash - 6537004464186396918
# UPDATING CATCODES: categorical value for field oaid_hash - 5157939743440724660
# UPDATING CATCODES: categorical value for field oaid_hash - 5380910328448596312
# UPDATING CATCODES: categorical value for field oaid_hash - 8585073424754632825
# UPDATING CATCODES: categorical value for field oaid_hash - 8212556321845734673
# UPDATING CATCODES: categorical value for field oaid_hash - 1371072635509318252
# UPDATING CATCODES: categorical value for field oaid_hash - 7119140200451451499
# UPDATING CATCODES: categorical value for field oaid_hash - 5215222393094071737
# UPDATING CATCODES: categorical value for field oaid_hash - 1102669425603854889
# UPDATING CATCODES: categorical value for field oaid_hash - 8970705720267235211
# UPDATING CATCODES: categorical value for field oaid_hash - 2521895603443866206
# UPDATING CATCODES: categorical value for field oaid_hash - 9088557926225098190
# UPDATING CATCODES: categorical value for field oaid_hash - 2587389861778710188
# UPDATING CATCODES: categorical value for field oaid_hash - 7689642572825010321
# UPDATING CATCODES: categorical value for field oaid_hash - 840219743054001640
# UPDATING CATCODES: categorical value for field oaid_hash - 5187935234771604596
# UPDATING CATCODES: categorical value for field oaid_hash - 9111895323528530866
# UPDATING CATCODES: categorical value for field oaid_hash - 6951391752597746603
# UPDATING CATCODES: categorical value for field oaid_hash - 3831323296603505600
# UPDATING CATCODES: categorical value for field oaid_hash - 8080340343477060746
# UPDATING CATCODES: categorical value for field oaid_hash - 841766407780364783
# UPDATING CATCODES: categorical value for field oaid_hash - 3313845023516222965
# UPDATING CATCODES: categorical value for field oaid_hash - 2225216264307777430
# UPDATING CATCODES: categorical value for field oaid_hash - 3888778191046784260
# UPDATING CATCODES: categorical value for field oaid_hash - 7681485319940252133
# UPDATING CATCODES: categorical value for field oaid_hash - 2758694648845388378
# UPDATING CATCODES: categorical value for field oaid_hash - 7217783381437263403
# UPDATING CATCODES: categorical value for field oaid_hash - 495552864793577709
# UPDATING CATCODES: categorical value for field oaid_hash - 4813251267810041428
# UPDATING CATCODES: categorical value for field oaid_hash - 7973035698081395906
# UPDATING CATCODES: categorical value for field oaid_hash - 6943636619844895814
# UPDATING CATCODES: categorical value for field oaid_hash - 6538185412445092021
# UPDATING CATCODES: categorical value for field oaid_hash - 6745071139370014316
# UPDATING CATCODES: categorical value for field oaid_hash - 7403630793400070883
# UPDATING CATCODES: categorical value for field oaid_hash - 684846738290507292
# UPDATING CATCODES: categorical value for field oaid_hash - 2728122347483996769
# UPDATING CATCODES: categorical value for field oaid_hash - 9219451944418694938
# UPDATING CATCODES: categorical value for field oaid_hash - 2435021868092481216
# UPDATING CATCODES: categorical value for field oaid_hash - 2292240389016374514
# UPDATING CATCODES: categorical value for field oaid_hash - 1948636997255171015
# UPDATING CATCODES: categorical value for field oaid_hash - 2890718152668627077
# UPDATING CATCODES: categorical value for field oaid_hash - 1600978544213796845
# UPDATING CATCODES: categorical value for field oaid_hash - 1992252582419778875
# UPDATING CATCODES: categorical value for field oaid_hash - 2394377081012345191
# UPDATING CATCODES: categorical value for field oaid_hash - 7498641841217344100
# UPDATING CATCODES: categorical value for field oaid_hash - 6511428668174838697
# UPDATING CATCODES: categorical value for field oaid_hash - 5526199050386377704
# UPDATING CATCODES: categorical value for field oaid_hash - 6268507452323192452
# UPDATING CATCODES: categorical value for field oaid_hash - 4192209606482497745
# UPDATING CATCODES: categorical value for field oaid_hash - 6544604930546638664
# UPDATING CATCODES: categorical value for field oaid_hash - 4416498634326691191
# UPDATING CATCODES: categorical value for field oaid_hash - 8850397854485712847
# UPDATING CATCODES: categorical value for field oaid_hash - 7388278427939787894
# UPDATING CATCODES: categorical value for field oaid_hash - 7180067480798064141
# UPDATING CATCODES: categorical value for field oaid_hash - 8872468579665396228
# UPDATING CATCODES: categorical value for field oaid_hash - 5276918969340563479
# UPDATING CATCODES: categorical value for field oaid_hash - 5536705777980700643
# UPDATING CATCODES: categorical value for field oaid_hash - 7508350379062592370
# UPDATING CATCODES: categorical value for field oaid_hash - 5682492680726835103
# UPDATING CATCODES: categorical value for field oaid_hash - 5943659207191649011
# UPDATING CATCODES: categorical value for field oaid_hash - 6159879982918649362
# UPDATING CATCODES: categorical value for field oaid_hash - 3097415782536336441
# UPDATING CATCODES: categorical value for field oaid_hash - 1926663095813750852
# UPDATING CATCODES: categorical value for field oaid_hash - 7181669494646988903
# UPDATING CATCODES: categorical value for field oaid_hash - 2646963300651869367
# UPDATING CATCODES: categorical value for field oaid_hash - 2280273482053617241
# UPDATING CATCODES: categorical value for field oaid_hash - 2796533698398250355
# UPDATING CATCODES: categorical value for field oaid_hash - 640795711875610294
# UPDATING CATCODES: categorical value for field oaid_hash - 2578275252963128914
# UPDATING CATCODES: categorical value for field oaid_hash - 2903401945602079660
# UPDATING CATCODES: categorical value for field oaid_hash - 2763768589976392053
# UPDATING CATCODES: categorical value for field oaid_hash - 6230905347990683332
# UPDATING CATCODES: categorical value for field oaid_hash - 6061068284015861757
# UPDATING CATCODES: categorical value for field oaid_hash - 6895862357698575174
# UPDATING CATCODES: categorical value for field oaid_hash - 5480998275328978906
# UPDATING CATCODES: categorical value for field oaid_hash - 8914467407907262541
# UPDATING CATCODES: categorical value for field oaid_hash - 8915895631827634462
# UPDATING CATCODES: categorical value for field oaid_hash - 7050789046668323789
# UPDATING CATCODES: categorical value for field oaid_hash - 1771187925923790627
# UPDATING CATCODES: categorical value for field oaid_hash - 4517936136579263776
# UPDATING CATCODES: categorical value for field oaid_hash - 8795215595964311185
# UPDATING CATCODES: categorical value for field oaid_hash - 7191584571459226120
# UPDATING CATCODES: categorical value for field oaid_hash - 7382494871785827205
# UPDATING CATCODES: categorical value for field oaid_hash - 4293265783338992461
# UPDATING CATCODES: categorical value for field oaid_hash - 6913636479982741043
# UPDATING CATCODES: categorical value for field oaid_hash - 3856243702575767975
# UPDATING CATCODES: categorical value for field oaid_hash - 9100122728943020778
# UPDATING CATCODES: categorical value for field oaid_hash - 7480206855400996991
# UPDATING CATCODES: categorical value for field oaid_hash - 7976738433645448167
# UPDATING CATCODES: categorical value for field oaid_hash - 653205602671782321
# UPDATING CATCODES: categorical value for field oaid_hash - 6971620650125465355
# UPDATING CATCODES: categorical value for field oaid_hash - 4473470109919078601
# UPDATING CATCODES: categorical value for field oaid_hash - 2052102719161500127
# UPDATING CATCODES: categorical value for field oaid_hash - 1134726313550586530
# UPDATING CATCODES: categorical value for field oaid_hash - 2362202686553902545
# UPDATING CATCODES: categorical value for field oaid_hash - 1663787530994727252
# UPDATING CATCODES: categorical value for field oaid_hash - 4086007158152351741
# UPDATING CATCODES: categorical value for field oaid_hash - 7277665771913969196
# UPDATING CATCODES: categorical value for field oaid_hash - 791012772692331692
# UPDATING CATCODES: categorical value for field oaid_hash - 7162698268367338486
# UPDATING CATCODES: categorical value for field oaid_hash - 7137840179229760043
# UPDATING CATCODES: categorical value for field oaid_hash - 168845849578306797
# UPDATING CATCODES: categorical value for field oaid_hash - 6940204625974551719
# UPDATING CATCODES: categorical value for field oaid_hash - 1203710198943829066
# UPDATING CATCODES: categorical value for field oaid_hash - 2088003111748613964
# UPDATING CATCODES: categorical value for field oaid_hash - 5428218156002953543
# UPDATING CATCODES: categorical value for field oaid_hash - 6476385190060308254
# UPDATING CATCODES: categorical value for field oaid_hash - 3768397815720559446
# UPDATING CATCODES: categorical value for field oaid_hash - 7950003243697908137
# UPDATING CATCODES: categorical value for field oaid_hash - 6548764686004721894
# UPDATING CATCODES: categorical value for field oaid_hash - 2952170242784490890
# UPDATING CATCODES: categorical value for field oaid_hash - 3238946825870492233
# UPDATING CATCODES: categorical value for field oaid_hash - 3736971407928914348
# UPDATING CATCODES: categorical value for field oaid_hash - 2916876002666379497
# UPDATING CATCODES: categorical value for field oaid_hash - 923029355580901794
# UPDATING CATCODES: categorical value for field oaid_hash - 6004842183023063473
# UPDATING CATCODES: categorical value for field oaid_hash - 9042295700308775143
# UPDATING CATCODES: categorical value for field oaid_hash - 154737658784664960
# UPDATING CATCODES: categorical value for field oaid_hash - 178364897835459556
# UPDATING CATCODES: categorical value for field oaid_hash - 6943747121646032524
# UPDATING CATCODES: categorical value for field oaid_hash - 1865325762330074499
# UPDATING CATCODES: categorical value for field oaid_hash - 6519800714049542947
# UPDATING CATCODES: categorical value for field oaid_hash - 7185458173441081711
# UPDATING CATCODES: categorical value for field oaid_hash - 4870911899472032102
# UPDATING CATCODES: categorical value for field oaid_hash - 7522314879280583173
# UPDATING CATCODES: categorical value for field oaid_hash - 2762360446650792168
# UPDATING CATCODES: categorical value for field oaid_hash - 251510749431443548
# UPDATING CATCODES: categorical value for field oaid_hash - 4511826294047298957
# UPDATING CATCODES: categorical value for field oaid_hash - 7617081699441156479
# UPDATING CATCODES: categorical value for field oaid_hash - 7115512570681366006
# UPDATING CATCODES: categorical value for field oaid_hash - 3679451172535227677
# UPDATING CATCODES: categorical value for field oaid_hash - 3917265059020339211
# UPDATING CATCODES: categorical value for field oaid_hash - 8389240380501766740
# UPDATING CATCODES: categorical value for field oaid_hash - 2017582880029192897
# UPDATING CATCODES: categorical value for field oaid_hash - 1561780170973309814
# UPDATING CATCODES: categorical value for field oaid_hash - 2543724795449668387
# UPDATING CATCODES: categorical value for field oaid_hash - 1686967754876073098
# UPDATING CATCODES: categorical value for field oaid_hash - 5154091358764783916
# UPDATING CATCODES: categorical value for field oaid_hash - 1865012451836385750
# UPDATING CATCODES: categorical value for field oaid_hash - 7713168249303753015
# UPDATING CATCODES: categorical value for field oaid_hash - 6846049565664391597
# UPDATING CATCODES: categorical value for field oaid_hash - 1254267580474101924
# UPDATING CATCODES: categorical value for field oaid_hash - 9056917713616837297
# UPDATING CATCODES: categorical value for field oaid_hash - 889303367868703350
# UPDATING CATCODES: categorical value for field oaid_hash - 8582087944754990589
# UPDATING CATCODES: categorical value for field oaid_hash - 1636443887944079755
# UPDATING CATCODES: categorical value for field oaid_hash - 4008703884270539749
# UPDATING CATCODES: categorical value for field oaid_hash - 4508313751564802130
# UPDATING CATCODES: categorical value for field oaid_hash - 2864870521114510708
# UPDATING CATCODES: categorical value for field oaid_hash - 2847378454252623574
# UPDATING CATCODES: categorical value for field oaid_hash - 8218552814628619645
# UPDATING CATCODES: categorical value for field oaid_hash - 4131904164588992903
# UPDATING CATCODES: categorical value for field oaid_hash - 6861751410029257528
# UPDATING CATCODES: categorical value for field oaid_hash - 195720412505148266
# ...
# UPDATING CATCODES: categorical value for field oaid_hash - 6993562141884792192
# UPDATING CATCODES: categorical value for field oaid_hash - 875844272353949416
# UPDATING CATCODES: categorical value for field oaid_hash - 793827613307233196
# UPDATING CATCODES: categorical value for field oaid_hash - 5890971909739470372
# UPDATING CATCODES: categorical value for field oaid_hash - 4947685377292779138
# UPDATING CATCODES: categorical value for field oaid_hash - 972650925989711017
# UPDATING CATCODES: categorical value for field oaid_hash - 1124460906540175845
# UPDATING CATCODES: categorical value for field oaid_hash - 8323326095659591017
# UPDATING CATCODES: categorical value for field oaid_hash - 3842389300493871732
# UPDATING CATCODES: categorical value for field oaid_hash - 2988923281782254098
# UPDATING CATCODES: categorical value for field oaid_hash - 4445923149958397116
# UPDATING CATCODES: categorical value for field oaid_hash - 2638857782700306323
# UPDATING CATCODES: categorical value for field oaid_hash - 5290854173153893955
# UPDATING CATCODES: categorical value for field oaid_hash - 7143650308207464741
# UPDATING CATCODES: categorical value for field oaid_hash - 5552058240967279502
# UPDATING CATCODES: categorical value for field oaid_hash - 2385456183173297282
# UPDATING CATCODES: categorical value for field oaid_hash - 8209816653340384457
# UPDATING CATCODES: categorical value for field oaid_hash - 3518521540735610661
# UPDATING CATCODES: categorical value for field oaid_hash - 2063965024525088011
# UPDATING CATCODES: categorical value for field oaid_hash - 4603120335026494214
# UPDATING CATCODES: categorical value for field oaid_hash - 3310385092451799263
# UPDATING CATCODES: categorical value for field oaid_hash - 2504036653511735292
# UPDATING CATCODES: categorical value for field oaid_hash - 1394598191889933309
# UPDATING CATCODES: categorical value for field oaid_hash - 6514722018738650487
# UPDATING CATCODES: categorical value for field oaid_hash - 5799089252269430078
# UPDATING CATCODES: categorical value for field oaid_hash - 5890074852771910860
# UPDATING CATCODES: categorical value for field oaid_hash - 7813904499421248521
# UPDATING CATCODES: categorical value for field oaid_hash - 1127410679445046025
# UPDATING CATCODES: categorical value for field oaid_hash - 2951489434406308513
# UPDATING CATCODES: categorical value for field oaid_hash - 95385929150525446
# UPDATING CATCODES: categorical value for field oaid_hash - 4899418970395330128
# UPDATING CATCODES: categorical value for field oaid_hash - 6218371584839108974
# UPDATING CATCODES: categorical value for field oaid_hash - 1531982450115929183
# UPDATING CATCODES: categorical value for field oaid_hash - 9137725086905001172
# UPDATING CATCODES: categorical value for field oaid_hash - 7057487571728170467
# UPDATING CATCODES: categorical value for field oaid_hash - 2045607037260946983
# UPDATING CATCODES: categorical value for field oaid_hash - 3672286939401912854
# UPDATING CATCODES: categorical value for field oaid_hash - 6741717759613708050
# UPDATING CATCODES: categorical value for field oaid_hash - 5341969521962718410
# UPDATING CATCODES: categorical value for field oaid_hash - 2668405376091920379
# UPDATING CATCODES: categorical value for field oaid_hash - 2254242338951077984
# UPDATING CATCODES: categorical value for field oaid_hash - 6337294968735911235
# UPDATING CATCODES: categorical value for field oaid_hash - 1761352931037270409
# UPDATING CATCODES: categorical value for field oaid_hash - 3685474460676092764
# UPDATING CATCODES: categorical value for field oaid_hash - 2840551804921244354
# UPDATING CATCODES: categorical value for field oaid_hash - 5123923610990284029
# UPDATING CATCODES: categorical value for field oaid_hash - 2035422968250314144
# UPDATING CATCODES: categorical value for field oaid_hash - 5334714501298897722
# UPDATING CATCODES: categorical value for field oaid_hash - 690465150374675045
# UPDATING CATCODES: categorical value for field oaid_hash - 2233935481006526990
# UPDATING CATCODES: categorical value for field oaid_hash - 4117690381254254145
# UPDATING CATCODES: categorical value for field oaid_hash - 4480523546613563290
# UPDATING CATCODES: categorical value for field oaid_hash - 1477513740710507339
# UPDATING CATCODES: categorical value for field oaid_hash - 1671038745963369418
# UPDATING CATCODES: categorical value for field oaid_hash - 6290029971344443110
# UPDATING CATCODES: categorical value for field oaid_hash - 478972074375073255
# UPDATING CATCODES: categorical value for field oaid_hash - 7871246846290122932
# UPDATING CATCODES: categorical value for field oaid_hash - 8558195910203455338
# UPDATING CATCODES: categorical value for field oaid_hash - 1566691744591999615
# UPDATING CATCODES: categorical value for field oaid_hash - 2959406489533503622
# UPDATING CATCODES: categorical value for field oaid_hash - 504429414637470902
# UPDATING CATCODES: categorical value for field oaid_hash - 3073420864846727526
# UPDATING CATCODES: categorical value for field oaid_hash - 4865642409367119968
# UPDATING CATCODES: categorical value for field oaid_hash - 6398768741383173740
# UPDATING CATCODES: categorical value for field oaid_hash - 6202470945373111744
# UPDATING CATCODES: categorical value for field oaid_hash - 1108823581816894028
# UPDATING CATCODES: categorical value for field oaid_hash - 42382962661984543
# UPDATING CATCODES: categorical value for field oaid_hash - 1622097950842415906
# UPDATING CATCODES: categorical value for field oaid_hash - 6812661217570831042
# UPDATING CATCODES: categorical value for field oaid_hash - 5861396386983033281
# UPDATING CATCODES: categorical value for field oaid_hash - 4035009676400994783
# UPDATING CATCODES: categorical value for field oaid_hash - 2153930813483543029
# UPDATING CATCODES: categorical value for field oaid_hash - 1987685261085025832
# UPDATING CATCODES: categorical value for field oaid_hash - 937726016924626027
# UPDATING CATCODES: categorical value for field oaid_hash - 6514851454928663802
# UPDATING CATCODES: categorical value for field oaid_hash - 2944504626564730528
# UPDATING CATCODES: categorical value for field oaid_hash - 2936237987555034026
# UPDATING CATCODES: categorical value for field oaid_hash - 7017200699332051661
# UPDATING CATCODES: categorical value for field oaid_hash - 1689529190201902151
# UPDATING CATCODES: categorical value for field oaid_hash - 4813843036986850776
# UPDATING CATCODES: categorical value for field oaid_hash - 7759691214792098530
# UPDATING CATCODES: categorical value for field oaid_hash - 6709233468531838654
# UPDATING CATCODES: categorical value for field oaid_hash - 7672457803058514257
# UPDATING CATCODES: categorical value for field oaid_hash - 4773502815990074490
# UPDATING CATCODES: categorical value for field oaid_hash - 4920034976388665699
# UPDATING CATCODES: categorical value for field oaid_hash - 929563746299506844
# UPDATING CATCODES: categorical value for field oaid_hash - 9014986192925811176
# UPDATING CATCODES: categorical value for field oaid_hash - 1177579107113326791
# UPDATING CATCODES: categorical value for field oaid_hash - 5689978470501632050
# UPDATING CATCODES: categorical value for field oaid_hash - 3951000016211704848
# UPDATING CATCODES: categorical value for field oaid_hash - 5910794269707711237
# UPDATING CATCODES: categorical value for field oaid_hash - 7703769141078737524
# UPDATING CATCODES: categorical value for field oaid_hash - 7227626953352473600
# UPDATING CATCODES: categorical value for field oaid_hash - 4719914775219396419
# UPDATING CATCODES: categorical value for field oaid_hash - 7725437167727040042
# UPDATING CATCODES: categorical value for field oaid_hash - 6331716813370219453
# UPDATING CATCODES: categorical value for field oaid_hash - 2590313808803398842
# UPDATING CATCODES: categorical value for field oaid_hash - 383665252128707746
# UPDATING CATCODES: categorical value for field oaid_hash - 4277455635579715423
# UPDATING CATCODES: categorical value for field oaid_hash - 1877319669533521021
# UPDATING CATCODES: categorical value for field oaid_hash - 6263055941658769444
# UPDATING CATCODES: categorical value for field oaid_hash - 9064039615295487966
# UPDATING CATCODES: categorical value for field oaid_hash - 3098045245820249400
# UPDATING CATCODES: categorical value for field oaid_hash - 8238765635771464679
# UPDATING CATCODES: categorical value for field oaid_hash - 1635262819671407522
# UPDATING CATCODES: categorical value for field oaid_hash - 7473421959478914774
# UPDATING CATCODES: categorical value for field oaid_hash - 8907737431301816632
# UPDATING CATCODES: categorical value for field oaid_hash - 4960905875810697602
# UPDATING CATCODES: categorical value for field oaid_hash - 4899200402011002173
# UPDATING CATCODES: categorical value for field oaid_hash - 283771396837412219
# UPDATING CATCODES: categorical value for field oaid_hash - 3948185138621688069
# UPDATING CATCODES: categorical value for field oaid_hash - 3312409123614216695
# UPDATING CATCODES: categorical value for field oaid_hash - 4380879207124251675
# UPDATING CATCODES: categorical value for field oaid_hash - 8724204249667123614
# UPDATING CATCODES: categorical value for field oaid_hash - 1248442784754284814
# UPDATING CATCODES: categorical value for field oaid_hash - 5516952212205813452
# UPDATING CATCODES: categorical value for field oaid_hash - 6556573846475839542
# UPDATING CATCODES: categorical value for field oaid_hash - 7076688868459519074
# UPDATING CATCODES: categorical value for field oaid_hash - 77318887767537959
# UPDATING CATCODES: categorical value for field oaid_hash - 7419487072947904890
# UPDATING CATCODES: categorical value for field oaid_hash - 3014329959622047731
# UPDATING CATCODES: categorical value for field oaid_hash - 5752344924321656211
# UPDATING CATCODES: categorical value for field oaid_hash - 1190514147476921627
# UPDATING CATCODES: categorical value for field oaid_hash - 3565384020142078380
# UPDATING CATCODES: categorical value for field oaid_hash - 6013249610111953004
# UPDATING CATCODES: categorical value for field oaid_hash - 6401502075813802920
# UPDATING CATCODES: categorical value for field oaid_hash - 1610177020672218619
# UPDATING CATCODES: categorical value for field oaid_hash - 6381139797334576049
# UPDATING CATCODES: categorical value for field oaid_hash - 719460664893389117
# UPDATING CATCODES: categorical value for field oaid_hash - 6047851747402965883
# UPDATING CATCODES: categorical value for field oaid_hash - 7180046407772142200
# UPDATING CATCODES: categorical value for field oaid_hash - 5528686776373405929
# UPDATING CATCODES: categorical value for field oaid_hash - 3581714727706996417
# UPDATING CATCODES: categorical value for field oaid_hash - 6248065659806529852
# UPDATING CATCODES: categorical value for field oaid_hash - 4071849540293041988
# UPDATING CATCODES: categorical value for field oaid_hash - 695297188321965043
# UPDATING CATCODES: categorical value for field oaid_hash - 7846923498472371712
# UPDATING CATCODES: categorical value for field oaid_hash - 5024881738831581660
# UPDATING CATCODES: categorical value for field oaid_hash - 4367487349319622808
# UPDATING CATCODES: categorical value for field oaid_hash - 2975214813963280949
# UPDATING CATCODES: categorical value for field oaid_hash - 5520552302424698170
# UPDATING CATCODES: categorical value for field oaid_hash - 2912361857816584789
# UPDATING CATCODES: categorical value for field oaid_hash - 6956164522747105260
# UPDATING CATCODES: categorical value for field oaid_hash - 4675577552951217515
# UPDATING CATCODES: categorical value for field oaid_hash - 6380460752619792187
# UPDATING CATCODES: categorical value for field oaid_hash - 1028175819986536981
# UPDATING CATCODES: categorical value for field oaid_hash - 8061234820685971610
# UPDATING CATCODES: categorical value for field oaid_hash - 6991462870383273855
# UPDATING CATCODES: categorical value for field oaid_hash - 827811405628303083
# UPDATING CATCODES: categorical value for field oaid_hash - 2830495210449843116
# UPDATING CATCODES: categorical value for field oaid_hash - 2676798131420627911
# UPDATING CATCODES: categorical value for field oaid_hash - 4144930757046454833
# UPDATING CATCODES: categorical value for field oaid_hash - 5831646641900581825
# UPDATING CATCODES: categorical value for field oaid_hash - 7666500529907773452
# UPDATING CATCODES: categorical value for field oaid_hash - 8648380398016472737
# UPDATING CATCODES: categorical value for field oaid_hash - 8743027021742054616
# UPDATING CATCODES: categorical value for field oaid_hash - 8843987584459904401
# UPDATING CATCODES: categorical value for field oaid_hash - 4441654323788910822
# UPDATING CATCODES: categorical value for field oaid_hash - 6838316813004602995
# UPDATING CATCODES: categorical value for field oaid_hash - 5437220246751858640
# UPDATING CATCODES: categorical value for field oaid_hash - 3310386291759292327
# UPDATING CATCODES: categorical value for field oaid_hash - 8280025051834203651
# UPDATING CATCODES: categorical value for field oaid_hash - 4981449285068005583
# UPDATING CATCODES: categorical value for field oaid_hash - 193779093161317526
# UPDATING CATCODES: categorical value for field oaid_hash - 8974493065115720126
# UPDATING CATCODES: categorical value for field oaid_hash - 416491503015268145
# UPDATING CATCODES: categorical value for field oaid_hash - 2537446284909757611
# UPDATING CATCODES: categorical value for field oaid_hash - 8697559247080286391
# UPDATING CATCODES: categorical value for field oaid_hash - 5212717439149883858
# UPDATING CATCODES: categorical value for field oaid_hash - 2863260397810075460
# UPDATING CATCODES: categorical value for field oaid_hash - 5618535358399454941
# UPDATING CATCODES: categorical value for field oaid_hash - 4644589457386914326
# UPDATING CATCODES: categorical value for field oaid_hash - 5654023397706944344
# UPDATING CATCODES: categorical value for field oaid_hash - 77475114469683918
# UPDATING CATCODES: categorical value for field oaid_hash - 3117429980705957536
# UPDATING CATCODES: categorical value for field oaid_hash - 2593365587523008219
# UPDATING CATCODES: categorical value for field oaid_hash - 8462670171020166965
# UPDATING CATCODES: categorical value for field oaid_hash - 6779999556014406316
# UPDATING CATCODES: categorical value for field oaid_hash - 2641534340240423121
# UPDATING CATCODES: categorical value for field oaid_hash - 2875343898896834611
# UPDATING CATCODES: categorical value for field oaid_hash - 495235954886392623
# UPDATING CATCODES: categorical value for field oaid_hash - 6391832657691877203
# UPDATING CATCODES: categorical value for field oaid_hash - 5211884434796199890
# UPDATING CATCODES: categorical value for field oaid_hash - 5940999686586000085
# UPDATING CATCODES: categorical value for field oaid_hash - 4644037315187700614
# UPDATING CATCODES: categorical value for field oaid_hash - 3403225937021739419
# UPDATING CATCODES: categorical value for field oaid_hash - 2781900126009697057
# UPDATING CATCODES: categorical value for field oaid_hash - 2665051903122274572
# UPDATING CATCODES: categorical value for field oaid_hash - 5343639411151206991
# UPDATING CATCODES: categorical value for field oaid_hash - 9047241034780111501
# UPDATING CATCODES: categorical value for field oaid_hash - 2935773148218876911
# UPDATING CATCODES: categorical value for field oaid_hash - 2904920066074340362
# UPDATING CATCODES: categorical value for field oaid_hash - 2611522225384913396
# UPDATING CATCODES: categorical value for field oaid_hash - 3738298445722154463
# UPDATING CATCODES: categorical value for field oaid_hash - 4144229987626541291
# UPDATING CATCODES: categorical value for field oaid_hash - 4868405589539027521
# UPDATING CATCODES: categorical value for field oaid_hash - 6566069187004045552
# UPDATING CATCODES: categorical value for field oaid_hash - 2200536502912336374
# UPDATING CATCODES: categorical value for field os_id - 9
# UPDATING CATCODES: categorical value for field oaid_hash - 7000446104560698627
# UPDATING CATCODES: categorical value for field os_id - 10
# convert_to_ffm - START
# UPDATING CATCODES: categorical value for field oaid_hash - 9145182684780363377
# UPDATING CATCODES: categorical value for field oaid_hash - 6959051119881951657

# %%
import xlearn as xl

# %%
ffm_model = xl.create_ffm()
ffm_model.setTrain("data/train_ffm.txt")
ffm_model.setValidate("data/test_ffm.txt")

param = {
    'task': 'binary',
    'lr': 1e-2,
    'lambda': 0.002,
    'metric': 'auc',
    'k':7
}


ffm_model.fit(param, 'model.out')


ffm_model.setTest("data/test_ffm.txt")
ffm_model.setSigmoid()


ffm_model.predict('model.out', 'predict.txt')

y_pred = pd.read_csv('predict.txt', header=None)
trues = np.load('true.npy')
logloss = log_loss(trues, np.squeeze(np.array(y_pred)))

# %%
logloss
# Out:
# 0.14100359514155159

# %% [markdown]
# Сильно упростил для ffm, но при этом значение logloss тоже приемлимо, да и по времени сильно лучше, чем просто fm

# %%
roc_auc_score(trues, y_pred)
# Out:
# 0.7563869497292568

# %% [markdown]
# RocAuC тоже норм, можно еще фичи наверное погенерить и даже просто fm обогнать, в общем однозначно лайк
